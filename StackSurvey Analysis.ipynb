# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/survey_results_public.csv', index_col = 'ResponseId')
schema_df = pd.read_csv('Data/survey_results_schema.csv')
# Out:
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_11456\3679935928.py:1: DtypeWarning: Columns (0: AIThreat, 1: DatabaseWantEntry, 2: DevEnvWantEntry, 3: SOTagsWant Entry, 4: OpSysPersonal use, 5: CommPlatformHaveWorkedWith, 6: CommPlatformWantEntr, 7: AIModelsChoice, 8: SOComm, 9: AIAgentOrchWrite, 10: AIAgentExternal) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/survey_results_public.csv', index_col = 'ResponseId')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df.shape
# Out:
# (49191, 171)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 1 to 49191
# Columns: 171 entries, MainBranch to JobSat
# dtypes: float64(52), str(119)
# memory usage: 64.2 MB

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df.tail()
# Out:
#                                                    MainBranch  \
# ResponseId
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 49187       18-24 years old
# 49188       45-54 years old
# 49189       35-44 years old
# 49190       25-34 years old
# 49191       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 49187            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49188       Some college/university study without earning ...
# 49189         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49190          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49191       Some college/university study without earning ...
# ...

# %%
pd.set_option('display.max_column',150)
pd.set_option('display.max_rows', 100)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
schema_df
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %%
schema_df
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Age', 'EdLevel', 'Employment', 'EmploymentAddl',
#        'WorkExp', 'LearnCodeChoose', 'LearnCode', 'LearnCodeAI', 'AILearnHow',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=171)

# %%
df.AIAgentExtWrite
# Out:
# ResponseId
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 49187    NaN
# 49188    NaN
# 49189    NaN
# 49190    NaN
# 49191    NaN
# Name: AIAgentExtWrite, Length: 49191, dtype: str

# %%
df['AIAgentExternal']
# Out:
# ResponseId
# 1                                                 ChatGPT
# 2                                                     NaN
# 3        ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                                     ChatGPT;Claude Code
# 5                                                     NaN
#                                ...
# 49187                                                 NaN
# 49188                                                 NaN
# 49189                                                 NaN
# 49190                                                 NaN
# 49191                                                 NaN
# Name: AIAgentExternal, Length: 49191, dtype: str

# %%
df.loc[[2,3,4], ['AIAgentExternal', 'EmploymentAddl']]
# Out:
#                                              AIAgentExternal  \
# ResponseId
# 2                                                        NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                                        ChatGPT;Claude Code
#
#                EmploymentAddl
# ResponseId
# 2                         NaN
# 3           None of the above
# 4           None of the above

# %%
df.iloc[[2,3], [2, 8]]
# Out:
#                                                  EdLevel  \
# ResponseId
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                   LearnCodeAI
# ResponseId
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...

# %%
df.loc[[1, 2]]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
#
#                                                     EdLevel Employment  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 2                       Associate degree (A.A., A.S., etc.)   Employed
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# ...

# %%
schema_df.columns
# Out:
# Index(['qid', 'qname', 'question', 'type', 'sub', 'sq_id'], dtype='str')

# %%
schema_df.head()
# Out:
#      qid          qname                                           question  \
# 0  QID18  TechEndorse_1  What attracts you to a technology or causes yo...
# 1  QID18  TechEndorse_2  What attracts you to a technology or causes yo...
# 2  QID18  TechEndorse_3  What attracts you to a technology or causes yo...
# 3  QID18  TechEndorse_4  What attracts you to a technology or causes yo...
# 4  QID18  TechEndorse_5  What attracts you to a technology or causes yo...
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# 1   RO                          Easy-to-use API    2.0
# 2   RO                  Robust and complete API    3.0
# 3   RO     Customizable and manageable codebase    4.0
# 4   RO                   Reputation for quality    5.0

# %%
schema_df.set_index('qname', inplace = True)

# %%
schema_df.sort_index(ascending=True, inplace = True)

# %%
schema_df
# Out:
#                       qid                                           question  \
# qname
# AIAcc               QID80  How much do you trust the accuracy of the outp...
# AIAgentChallenges   QID88  To what extent do you agree with the following...
# AIAgentChange       QID83  Have AI tools or AI agents changed how you com...
# AIAgentExtWrite    QID104  Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal     QID92  You indicated you use or develop AI agents as ...
# ...                   ...                                                ...
# WebframeChoice      QID47  Did you work with web frameworks and web techn...
# WebframeHaveEntry   QID58  Were the web frameworks and web technologies y...
# WebframeWantEntry   QID59  Were the web frameworks and web technologies y...
# WorkExp             QID14  How many years of professional work experience...
# YearsCode           QID13  Including any education, how many years have y...
#
# ...

# %%
schema_df.loc['AIAgentExtWrite', 'question']
# Out:
# 'Was the out-of-the-box agents, copilots or assistants you used in the past year not listed above?  Please write them below separated by a comma and space if there are more than one.'

# %%
schema_df
# Out:
#                       qid                                           question  \
# qname
# AIAcc               QID80  How much do you trust the accuracy of the outp...
# AIAgentChallenges   QID88  To what extent do you agree with the following...
# AIAgentChange       QID83  Have AI tools or AI agents changed how you com...
# AIAgentExtWrite    QID104  Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal     QID92  You indicated you use or develop AI agents as ...
# ...                   ...                                                ...
# WebframeChoice      QID47  Did you work with web frameworks and web techn...
# WebframeHaveEntry   QID58  Were the web frameworks and web technologies y...
# WebframeWantEntry   QID59  Were the web frameworks and web technologies y...
# WorkExp             QID14  How many years of professional work experience...
# YearsCode           QID13  Including any education, how many years have y...
#
# ...

# %%
pd.set_option('display.max_rows', 139)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
schema_df.loc['CompTotal' : 'Database']
# Out:
#              qid                                           question    type  \
# qname
# CompTotal  QID22  What is your current total <b>annual</b> compe...      TE
# Country    QID20                                 Where do you live?      MC
# Currency   QID21  Which currency do you use day-to-day? If your ...      MC
# Database   QID35  Which <b>database environments </b>have you do...  Matrix
#
#            sub  sq_id
# qname
# CompTotal  NaN    NaN
# Country    NaN    NaN
# Currency   NaN    NaN
# Database   NaN    NaN

# %%
schema_df.loc['CompTotal', 'question']
# Out:
# 'What is your current total <b>annual</b> compensation (salary, bonuses, and perks, before taxes and deductions) in terms of your day-to-day currency?  Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent yearly salary. If you prefer not to answer, please leave the box empty. '

# %%
filt = (df['CompTotal'] > 100000)

# %%
df.loc[filt, ['Country','MainBranch', 'Employment', 'CompTotal']]
# Out:
#                              Country                      MainBranch  \
# ResponseId
# 3                            Ukraine  I am a developer by profession
# 6                            Ukraine  I am a developer by profession
# 11                           Ukraine  I am a developer by profession
# 27                           Ireland  I am a developer by profession
# 28                            Sweden  I am a developer by profession
# ...                              ...                             ...
# 49145                        Romania  I am a developer by profession
# 49146       United States of America  I am a developer by profession
# 49156                          India  I am a developer by profession
# 49177                          Kenya  I am a developer by profession
# 49180                         Brazil  I am a developer by profession
#
#                                                    Employment  CompTotal
# ResponseId
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1                         Bash/Shell (all shells);Dart;SQL
# 2                                                     Java
# 3                      Dart;HTML/CSS;JavaScript;TypeScript
# 4                                          Java;Kotlin;SQL
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#                                ...
# 49187                                                  NaN
# 49188                                                  NaN
# 49189                                                  NaN
# 49190                                                  NaN
# 49191                                                  NaN
# Name: LanguageHaveWorkedWith, Length: 49191, dtype: str

# %%
filt_lang = (df['LanguageHaveWorkedWith'].str.contains('Python', na = False))

# %%
df.loc[filt_lang, ['Country', 'WorkExp', 'LanguageHaveWorkedWith']]
# Out:
#                                                       Country  WorkExp  \
# ResponseId
# 5                                                     Ukraine     21.0
# 8                                                     Ukraine     22.0
# 9                                                     Ukraine      9.0
# 16                                                      India      5.0
# 18                                                     Greece      1.0
# ...                                                       ...      ...
# 49144       United Kingdom of Great Britain and Northern I...      4.0
# 49146                                United States of America     18.0
# 49176                                                 Germany      4.0
# 49177                                                   Kenya      5.0
# 49178                                United States of America      9.0
#
#                                        LanguageHaveWorkedWith
# ResponseId
# ...

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df['ConvertedCompYearly']
# Out:
# ResponseId
# 1         61256.0
# 2        104413.0
# 3         53061.0
# 4         36197.0
# 5         60000.0
#            ...
# 49187         NaN
# 49188         NaN
# 49189         NaN
# 49190         NaN
# 49191         NaN
# Name: ConvertedCompYearly, Length: 49191, dtype: float64

# %%
schema_df
pd.set_option('display.max_rows', 139)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
df.rename(columns = {'ConvertedCompYearly': 'SalaryUSD'}, inplace = True)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df['SalaryUSD']
# Out:
# ResponseId
# 1         61256.0
# 2        104413.0
# 3         53061.0
# 4         36197.0
# 5         60000.0
#            ...
# 49187         NaN
# 49188         NaN
# 49189         NaN
# 49190         NaN
# 49191         NaN
# Name: SalaryUSD, Length: 49191, dtype: float64

# %%
df['AIModelsChoice'].map({'Yes': 'True', 'No': 'False'})
# Out:
# ResponseId
# 1         True
# 2         True
# 3         True
# 4        False
# 5         True
#          ...
# 49187      NaN
# 49188      NaN
# 49189      NaN
# 49190      NaN
# 49191      NaN
# Name: AIModelsChoice, Length: 49191, dtype: str

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df['AIModelsChoice'] = df['AIModelsChoice'].map({'Yes': 'True', 'No': 'False'})

# %%
df['AIModelsChoice'].head(20)
# Out:
# ResponseId
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9       NaN
# 10    False
# 11     True
# 12    False
# 13      NaN
# 14      NaN
# 15    False
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# Name: AIModelsChoice, dtype: str

# %%
highest_paid = df.sort_values(by='SalaryUSD', ascending=False)
highest_paid[['SalaryUSD', 'Country']]
# Out:
#              SalaryUSD                       Country
# ResponseId
# 34268       50000000.0      United States of America
# 28701       33552715.0                       Ukraine
# 43144       18387548.0                        Poland
# 35354       15430267.0  Iran, Islamic Republic of...
# 45972       13921760.0                   Netherlands
# ...                ...                           ...
# 49187              NaN                           NaN
# 49188              NaN                           NaN
# 49189              NaN                         Italy
# 49190              NaN                           NaN
# 49191              NaN                           NaN
#
# [49191 rows x 2 columns]

# %%
highest_paid
# Out:
#                                                    MainBranch  \
# ResponseId
# 34268                             I code primarily as a hobby
# 28701                          I am a developer by profession
# 43144                             I code primarily as a hobby
# 35354                          I am a developer by profession
# 45972       I work with developers or my work supports dev...
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 34268       55-64 years old
# 28701       35-44 years old
# 43144       18-24 years old
# 35354       35-44 years old
# 45972       55-64 years old
# ...

# %%
df.sort_values(by=['SalaryUSD','Country'], ascending=[False,True], inplace=True)

# %%
df[['SalaryUSD', 'Country']].head(8)
# Out:
#              SalaryUSD                       Country
# ResponseId
# 34268       50000000.0      United States of America
# 28701       33552715.0                       Ukraine
# 43144       18387548.0                        Poland
# 35354       15430267.0  Iran, Islamic Republic of...
# 45972       13921760.0                   Netherlands
# 48429       10000000.0                       Ukraine
# 24901        9531653.0                         India
# 10026        9000000.0      United States of America

# %%
df['Country'].sort_values().head(26)
# Out:
# ResponseId
# 7925     Afghanistan
# 38609    Afghanistan
# 6010     Afghanistan
# 7167     Afghanistan
# 40967    Afghanistan
# 44797    Afghanistan
# 27099    Afghanistan
# 45925    Afghanistan
# 40307    Afghanistan
# 19816    Afghanistan
# 15708    Afghanistan
# 6836     Afghanistan
# 7077     Afghanistan
# 11874        Albania
# 16850        Albania
# 2023         Albania
# 33940        Albania
# 37731        Albania
# 3185         Albania
# 22400        Albania
# 14758        Albania
# 35934        Albania
# 16239        Albania
# 44946        Albania
# 25304        Albania
# 35184        Albania
# Name: Country, dtype: str

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 34268                             I code primarily as a hobby
# 28701                          I am a developer by profession
# 43144                             I code primarily as a hobby
# 35354                          I am a developer by profession
# 45972       I work with developers or my work supports dev...
# ...                                                       ...
# 49186                          I am a developer by profession
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 34268       55-64 years old
# 28701       35-44 years old
# 43144       18-24 years old
# 35354       35-44 years old
# 45972       55-64 years old
# ...

# %%
df[['SalaryUSD', 'Employment']].head(8)
# Out:
#              SalaryUSD                                         Employment
# ResponseId
# 34268       50000000.0  Independent contractor, freelancer, or self-em...
# 28701       33552715.0                                           Employed
# 43144       18387548.0                                           Employed
# 35354       15430267.0                                           Employed
# 45972       13921760.0                                           Employed
# 48429       10000000.0                                            Student
# 24901        9531653.0                                           Employed
# 10026        9000000.0                                           Employed

# %%
df['SalaryUSD'].nlargest(15)
# Out:
# ResponseId
# 34268    50000000.0
# 28701    33552715.0
# 43144    18387548.0
# 35354    15430267.0
# 45972    13921760.0
# 48429    10000000.0
# 24901     9531653.0
# 10026     9000000.0
# 37353     6890299.0
# 30729     6371285.0
# 40419     6000000.0
# 19537     5810837.0
# 28056     5000000.0
# 14874     4706124.0
# 48024     3900562.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].nsmallest(15)
# Out:
# ResponseId
# 34866    1.0
# 41683    1.0
# 34568    1.0
# 27893    1.0
# 28178    1.0
# 42079    1.0
# 4581     1.0
# 16490    1.0
# 91       1.0
# 5911     1.0
# 13305    1.0
# 21035    1.0
# 26962    1.0
# 12408    1.0
# 39052    1.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(5, 'SalaryUSD')
# Out:
#                                                    MainBranch  \
# ResponseId
# 34866                          I am a developer by profession
# 41683       I am not primarily a developer, but I write co...
# 34568                          I am a developer by profession
# 27893                                   I am learning to code
# 28178                          I am a developer by profession
#
#                         Age  \
# ResponseId
# 34866       35-44 years old
# 41683       45-54 years old
# 34568       25-34 years old
# 27893       35-44 years old
# 28178       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 34866         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 41683         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34568                               Primary/elementary school
# 27893       Some college/university study without earning ...
# 28178          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# ...

# %%
df['SalaryUSD'].median()
# Out:
# np.float64(75320.0)

# %%
float(np.float64(75320.0))
# Out:
# 75320.0

# %%
float(df['SalaryUSD'].mean())
# Out:
# 101761.53990061386

# %%
df['SalaryUSD'].describe()
# Out:
# count    2.394700e+04
# mean     1.017615e+05
# std      4.617569e+05
# min      1.000000e+00
# 25%      3.817100e+04
# 50%      7.532000e+04
# 75%      1.205960e+05
# max      5.000000e+07
# Name: SalaryUSD, dtype: float64

# %%
df.describe()
# Out:
#             WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  42893.000000  43042.000000   35975.000000   35975.000000
# mean      13.367403     16.570861       7.867352       4.104211
# std       10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000       1.000000       1.000000
# 25%        5.000000      8.000000       7.000000       2.000000
# 50%       10.000000     14.000000       9.000000       4.000000
# 75%       20.000000     24.000000       9.000000       6.000000
# max      100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df['SalaryUSD'].count()
float(df['SalaryUSD'].count())
# Out:
# 23947.0

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 34268                             I code primarily as a hobby
# 28701                          I am a developer by profession
# 43144                             I code primarily as a hobby
# 35354                          I am a developer by profession
# 45972       I work with developers or my work supports dev...
# ...                                                       ...
# 49186                          I am a developer by profession
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 34268       55-64 years old
# 28701       35-44 years old
# 43144       18-24 years old
# 35354       35-44 years old
# 45972       55-64 years old
# ...

# %%
df['AIExplain'].value_counts()
# Out:
# AIExplain
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
schema_df.loc['SO_Actions_1', 'question']
# Out:
# 'When visiting Stack Overflow, which following activities are you most interested in?  Please rank the following so the first activity is what most interests you and last is your least interested activity.'

# %%
df['SO_Actions_1'].count()
# Out:
# np.int64(26260)

# %%
df['SO_Actions_1'].value_counts()
# Out:
# SO_Actions_1
# 2.0     4032
# 3.0     3791
# 4.0     2969
# 7.0     2778
# 8.0     2611
# 6.0     2582
# 5.0     2566
# 9.0     2153
# 1.0     2138
# 10.0     217
# 11.0     129
# 12.0     110
# 13.0      97
# 14.0      79
# 15.0       8
# Name: count, dtype: int64

# %%
df['SO_Actions_1']
# Out:
# ResponseId
# 34268    NaN
# 28701    3.0
# 43144    9.0
# 35354    8.0
# 45972    NaN
#         ...
# 49186    NaN
# 49187    NaN
# 49188    NaN
# 49190    NaN
# 49191    NaN
# Name: SO_Actions_1, Length: 49191, dtype: float64

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
# Canada                                                  1305
# Ukraine                                                  964
# Poland                                                   888
# Netherlands                                              867
# Italy                                                    835
# Name: count, dtype: int64

# %%
df['Country']
# Out:
# ResponseId
# 34268        United States of America
# 28701                         Ukraine
# 43144                          Poland
# 35354    Iran, Islamic Republic of...
# 45972                     Netherlands
#                      ...
# 49186                             NaN
# 49187                             NaN
# 49188                             NaN
# 49190                             NaN
# 49191                             NaN
# Name: Country, Length: 49191, dtype: str

# %%
schema_df.loc['SOTags', 'question']
# Out:
# 'Which rising technology of the added as <b>new tag or tag subject area on Stack Overflow</b> in the last three years <strong>have you used</strong> regularly in the past year, and which do you <strong>want to work with</strong> over the next year? Please check all that apply.<br>\n '

# %%
df['SOAccount'].count()
# Out:
# np.int64(32797)

# %%
filt = df['Country'] == 'United States of America'
df[filt][['SOAccount', 'Country']]
# Out:
#                           SOAccount                   Country
# ResponseId
# 34268                           NaN  United States of America
# 10026                            No  United States of America
# 28059                           Yes  United States of America
# 5411                            Yes  United States of America
# 34976                           Yes  United States of America
# ...                             ...                       ...
# 49126       Not sure/can't remember  United States of America
# 49128                           Yes  United States of America
# 49146                           Yes  United States of America
# 49158                           NaN  United States of America
# 49178                            No  United States of America
#
# [7233 rows x 2 columns]

# %%
filt = df['Country'] == 'Nigeria'
df.loc[filt]['SOAccount'].value_counts()
# Out:
# SOAccount
# Yes                        134
# No                          21
# Not sure/can't remember     11
# Name: count, dtype: int64

# %%
country_grp = df.groupby('Country')

# %%
country_grp['SOAccount'].value_counts().head(40)
# Out:
# Country              SOAccount
# Afghanistan          Yes                          8
#                      No                           1
# Albania              Yes                         18
#                      Not sure/can't remember      3
# Algeria              Yes                         35
#                      No                           3
#                      Not sure/can't remember      3
# Andorra              Yes                          4
#                      No                           1
# Angola               Yes                          4
#                      Not sure/can't remember      1
# Antigua and Barbuda  Yes                          1
# Argentina            Yes                        171
#                      No                          32
#                      Not sure/can't remember      9
# Armenia              Yes                         20
#                      Not sure/can't remember      1
# ...

# %%
country_grp['SalaryUSD'].mean().head(20)
# Out:
# Country
# Afghanistan             12227.250000
# Albania                 47973.583333
# Algeria                 15935.400000
# Andorra                208763.750000
# Angola                 149857.250000
# Antigua and Barbuda         1.000000
# Argentina               46271.187500
# Armenia                 25016.363636
# Australia              115941.413005
# Austria                 79477.625000
# Azerbaijan              31202.333333
# Bahrain                 74240.500000
# Bangladesh              15520.941667
# Barbados                45450.500000
# Belarus                 58267.312500
# Belgium                 84666.275229
# Belize                 102121.000000
# Benin                    6816.333333
# Bhutan                  20361.000000
# Bolivia                 25214.307692
# Name: SalaryUSD, dtype: float64

# %%
country_grp['SalaryUSD'].mean().loc['Nigeria']
# Out:
# np.float64(63181.8431372549)

# %%
country_grp['SalaryUSD'].agg(['mean', 'median'])
# Out:
#                                                mean    median
# Country
# Afghanistan                            12227.250000    6121.0
# Albania                                47973.583333   26269.0
# Algeria                                15935.400000    6472.0
# Andorra                               208763.750000  200125.5
# Angola                                149857.250000    9578.0
# ...                                             ...       ...
# Venezuela, Bolivarian Republic of...   17008.400000    9000.0
# Viet Nam                              189894.192982    7642.0
# Yemen                                  17582.500000    5545.5
# Zambia                                  6594.875000    1966.5
# Zimbabwe                               25662.500000   17500.0
#
# [177 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['mean', 'median']).loc['Nigeria']
# Out:
# mean      63181.843137
# median     1291.000000
# Name: Nigeria, dtype: float64

# %%
NUMpython_user = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
NUMpython_user
# Out:
# Country
# Afghanistan                              4
# Albania                                 10
# Algeria                                 23
# Andorra                                  2
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...    23
# Viet Nam                                78
# Yemen                                    6
# Zambia                                   7
# Zimbabwe                                 7
# Name: LanguageHaveWorkedWith, Length: 177, dtype: int64

# %%
Num_users = df['Country'].value_counts()

# %%
Num_users
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
#                                                         ...
# Guinea-Bissau                                              1
# Niger                                                      1
# Palau                                                      1
# San Marino                                                 1
# Timor-Leste                                                1
# Name: count, Length: 177, dtype: int64

# %%
PCT_python_users = (NUMpython_user /Num_users) * 100

# %%
PCT_python_users
# Out:
# Country
# Afghanistan                             30.769231
# Albania                                 45.454545
# Algeria                                 46.938776
# Andorra                                 33.333333
# Angola                                  14.285714
#                                           ...
# Venezuela, Bolivarian Republic of...    48.936170
# Viet Nam                                53.793103
# Yemen                                   33.333333
# Zambia                                  53.846154
# Zimbabwe                                53.846154
# Length: 177, dtype: float64

# %%
df_pyth = pd.concat([Num_users, NUMpython_user], axis='columns', sort=False)
df_pyth
# Out:
#                                                     count  \
# Country
# United States of America                             7233
# Germany                                              3025
# India                                                2547
# United Kingdom of Great Britain and Northern Ir...   2042
# France                                               1409
# ...                                                   ...
# Guinea-Bissau                                           1
# Niger                                                   1
# Palau                                                   1
# San Marino                                              1
# Timor-Leste                                             1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                              4221
# Germany                                                               1685
# ...

# %%
df_pyth.rename(columns = {'count': 'Num_users', 'LanguageHaveWorkedWith': 'NUMpython_user'}, inplace=True)

# %%
df_pyth['PCT_python_users'] = (NUMpython_user/Num_users) * 100

# %%
df_pyth.columns = (x.lower() for x in df_pyth.columns)
df_pyth
# Out:
#                                                     num_users  numpython_user  \
# Country
# United States of America                                 7233            4221
# Germany                                                  3025            1685
# India                                                    2547            1162
# United Kingdom of Great Britain and Northern Ir...       2042            1027
# France                                                   1409             820
# ...                                                       ...             ...
# Guinea-Bissau                                               1               1
# Niger                                                       1               1
# Palau                                                       1               1
# San Marino                                                  1               0
# Timor-Leste                                                 1               0
#
# ...

# %%
df_pyth['Country'] = df['Country'].str.lower()
df_pyth
# Out:
#                                                     num_users  numpython_user  \
# Country
# United States of America                                 7233            4221
# Germany                                                  3025            1685
# India                                                    2547            1162
# United Kingdom of Great Britain and Northern Ir...       2042            1027
# France                                                   1409             820
# ...                                                       ...             ...
# Guinea-Bissau                                               1               1
# Niger                                                       1               1
# Palau                                                       1               1
# San Marino                                                  1               0
# Timor-Leste                                                 1               0
#
# ...

# %%
df_pyth.drop(columns = 'Country', inplace=True)

# %%
df_pyth.head()
# Out:
#                                                     num_users  numpython_user  \
# Country
# United States of America                                 7233            4221
# Germany                                                  3025            1685
# India                                                    2547            1162
# United Kingdom of Great Britain and Northern Ir...       2042            1027
# France                                                   1409             820
#
#                                                     pct_python_users
# Country
# United States of America                                   58.357528
# Germany                                                    55.702479
# India                                                      45.622301
# United Kingdom of Great Britain and Northern Ir...         50.293830
# France                                                     58.197303

# %%
df_pyth
# Out:
#                                                     num_users  numpython_user  \
# Country
# United States of America                                 7233            4221
# Germany                                                  3025            1685
# India                                                    2547            1162
# United Kingdom of Great Britain and Northern Ir...       2042            1027
# France                                                   1409             820
# ...                                                       ...             ...
# Guinea-Bissau                                               1               1
# Niger                                                       1               1
# Palau                                                       1               1
# San Marino                                                  1               0
# Timor-Leste                                                 1               0
#
# ...

# %%
df_pyth.index = df_pyth.index.str.lower()

# %%
df_pyth.reset_index(inplace=True)

# %%
df_pyth
# Out:
#                                                Country  num_users  \
# 0                             united states of america       7233
# 1                                              germany       3025
# 2                                                india       2547
# 3    united kingdom of great britain and northern i...       2042
# 4                                               france       1409
# ..                                                 ...        ...
# 172                                      guinea-bissau          1
# 173                                              niger          1
# 174                                              palau          1
# 175                                         san marino          1
# 176                                        timor-leste          1
#
#      numpython_user  pct_python_users
# 0              4221         58.357528
# 1              1685         55.702479
# 2              1162         45.622301
# ...

# %%
df_pyth['Country'] = df_pyth['Country'].str.upper()

# %%
df_pyth
# Out:
#                                                Country  num_users  \
# 0                             UNITED STATES OF AMERICA       7233
# 1                                              GERMANY       3025
# 2                                                INDIA       2547
# 3    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...       2042
# 4                                               FRANCE       1409
# ..                                                 ...        ...
# 172                                      GUINEA-BISSAU          1
# 173                                              NIGER          1
# 174                                              PALAU          1
# 175                                         SAN MARINO          1
# 176                                        TIMOR-LESTE          1
#
#      numpython_user  pct_python_users
# 0              4221         58.357528
# 1              1685         55.702479
# 2              1162         45.622301
# ...

# %%
df_pyth.columns = (x.lower() for x in df_pyth.columns)

# %%
df_pyth
# Out:
#                                                country  num_users  \
# 0                             UNITED STATES OF AMERICA       7233
# 1                                              GERMANY       3025
# 2                                                INDIA       2547
# 3    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...       2042
# 4                                               FRANCE       1409
# ..                                                 ...        ...
# 172                                      GUINEA-BISSAU          1
# 173                                              NIGER          1
# 174                                              PALAU          1
# 175                                         SAN MARINO          1
# 176                                        TIMOR-LESTE          1
#
#      numpython_user  pct_python_users
# 0              4221         58.357528
# 1              1685         55.702479
# 2              1162         45.622301
# ...

# %%
df_pyth.columns =  df_pyth.columns.str.title()

# %%
df_pyth
# Out:
#                                                Country  Num_Users  \
# 0                             UNITED STATES OF AMERICA       7233
# 1                                              GERMANY       3025
# 2                                                INDIA       2547
# 3    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...       2042
# 4                                               FRANCE       1409
# ..                                                 ...        ...
# 172                                      GUINEA-BISSAU          1
# 173                                              NIGER          1
# 174                                              PALAU          1
# 175                                         SAN MARINO          1
# 176                                        TIMOR-LESTE          1
#
#      Numpython_User  Pct_Python_Users
# 0              4221         58.357528
# 1              1685         55.702479
# 2              1162         45.622301
# ...

# %%
df_pyth['Country'] =  df_pyth['Country'].str.title()

# %%
df_pyth
# Out:
#                                                Country  Num_Users  \
# 0                             United States Of America       7233
# 1                                              Germany       3025
# 2                                                India       2547
# 3    United Kingdom Of Great Britain And Northern I...       2042
# 4                                               France       1409
# ..                                                 ...        ...
# 172                                      Guinea-Bissau          1
# 173                                              Niger          1
# 174                                              Palau          1
# 175                                         San Marino          1
# 176                                        Timor-Leste          1
#
#      Numpython_User  Pct_Python_Users
# 0              4221         58.357528
# 1              1685         55.702479
# 2              1162         45.622301
# ...

# %%
df_pyth.sort_values(by =  'Pct_Python_Users', ascending=False).head(20)
# Out:
#                                    Country  Num_Users  Numpython_User  \
# 174                                  Palau          1               1
# 154                               Suriname          2               2
# 155                                   Mali          2               2
# 152                            Saint Lucia          2               2
# 147                               Mongolia          3               3
# 167                                Lesotho          1               1
# 168                                 Guinea          1               1
# 171                                 Gambia          1               1
# 156                                  Haiti          2               2
# 173                                  Niger          1               1
# 172                          Guinea-Bissau          1               1
# 169                             Cape Verde          1               1
# ...

# %%
filt = df_pyth['Country'] == 'Nigeria'
df_pyth.loc[filt]
# Out:
#     Country  Num_Users  Numpython_User  Pct_Python_Users
# 38  Nigeria        199              80         40.201005

# %%
df_pyth.set_index('Country', inplace = True)

# %%
df_pyth
# Out:
#                                                     Num_Users  Numpython_User  \
# Country
# United States Of America                                 7233            4221
# Germany                                                  3025            1685
# India                                                    2547            1162
# United Kingdom Of Great Britain And Northern Ir...       2042            1027
# France                                                   1409             820
# ...                                                       ...             ...
# Guinea-Bissau                                               1               1
# Niger                                                       1               1
# Palau                                                       1               1
# San Marino                                                  1               0
# Timor-Leste                                                 1               0
#
# ...

# %%
df_pyth.loc['Nigeria']
# Out:
# Num_Users           199.000000
# Numpython_User       80.000000
# Pct_Python_Users     40.201005
# Name: Nigeria, dtype: float64

# %%
filt = df_pyth['Numpython_User'] == 80
df_pyth.loc[filt]
# Out:
#          Num_Users  Numpython_User  Pct_Python_Users
# Country
# Nigeria        199              80         40.201005

# %%
df['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          20278
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       12589
# Some college/university study without earning a degree                                 6182
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     3631
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2624
# Associate degree (A.A., A.S., etc.)                                                    1562
# Other (please specify):                                                                 701
# Primary/elementary school                                                               582
# Name: count, dtype: int64

# %%
df['EdLevel'].mode()
# Out:
# 0    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Name: EdLevel, dtype: str

# %%
country_grp['SalaryUSD'].mean()
# Out:
# Country
# Afghanistan                              12227.250000
# Albania                                  47973.583333
# Algeria                                  15935.400000
# Andorra                                 208763.750000
# Angola                                  149857.250000
#                                             ...
# Venezuela, Bolivarian Republic of...     17008.400000
# Viet Nam                                189894.192982
# Yemen                                    17582.500000
# Zambia                                    6594.875000
# Zimbabwe                                 25662.500000
# Name: SalaryUSD, Length: 177, dtype: float64

# %%
df.nlargest(2, 'SalaryUSD')['Country']
# Out:
# ResponseId
# 34268    United States of America
# 28701                     Ukraine
# Name: Country, dtype: str

# %%
filt = df['SalaryUSD'].nlargest(15).index
df.loc[filt]['Country']
# Out:
# ResponseId
# 34268                             United States of America
# 28701                                              Ukraine
# 43144                                               Poland
# 35354                         Iran, Islamic Republic of...
# 45972                                          Netherlands
# 48429                                              Ukraine
# 24901                                                India
# 10026                             United States of America
# 37353                                              Ukraine
# 30729                                               Brazil
# 40419                                             Viet Nam
# 19537                                              Nigeria
# 28056                                         South Africa
# 14874    United Kingdom of Great Britain and Northern I...
# 48024                                            Australia
# Name: Country, dtype: str

# %%
df.sort_values(by = 'SalaryUSD', ascending=False)[['SalaryUSD', 'WorkExp', 'WorkExp']].head(12)
# Out:
#              SalaryUSD  WorkExp  WorkExp
# ResponseId
# 34268       50000000.0     10.0     10.0
# 28701       33552715.0     20.0     20.0
# 43144       18387548.0     10.0     10.0
# 35354       15430267.0     15.0     15.0
# 45972       13921760.0     30.0     30.0
# 48429       10000000.0      NaN      NaN
# 24901        9531653.0      1.0      1.0
# 10026        9000000.0      2.0      2.0
# 37353        6890299.0     15.0     15.0
# 30729        6371285.0     17.0     17.0
# 40419        6000000.0     10.0     10.0
# 19537        5810837.0     20.0     20.0

# %%
df.sort_values(by = 'WorkExp', ascending=False)[['SalaryUSD', 'WorkExp']].head(20)
# Out:
#             SalaryUSD  WorkExp
# ResponseId
# 25195             NaN    100.0
# 45803             NaN    100.0
# 25121             NaN    100.0
# 28951             NaN    100.0
# 26559             NaN    100.0
# 15656             NaN    100.0
# 36625           182.0    100.0
# 38103            73.0    100.0
# 29192             NaN    100.0
# 12141           100.0    100.0
# 11065           100.0    100.0
# 29037             NaN    100.0
# 7882              NaN    100.0
# 44527             NaN    100.0
# 4934              NaN    100.0
# 16716        336327.0    100.0
# 43980             NaN    100.0
# 43619             NaN    100.0
# 22687             NaN    100.0
# 40983             NaN    100.0

# %%
schema_df.loc['WorkExp', 'question']
# Out:
# "How many years of professional work experience do you have? Please round to the nearest whole number, excluding any decimal points.  If your answer is '0', please leave blank."

# %%
df.sort_values(by = 'SalaryUSD', ascending=False)[['SalaryUSD', 'LanguageHaveWorkedWith']].head(12)
# Out:
#              SalaryUSD                             LanguageHaveWorkedWith
# ResponseId
# 34268       50000000.0                                                NaN
# 28701       33552715.0              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 43144       18387548.0                                                NaN
# 35354       15430267.0                                                NaN
# 45972       13921760.0                                        Java;Kotlin
# 48429       10000000.0  Assembly;C#;GDScript;HTML/CSS;JavaScript;Micro...
# 24901        9531653.0            HTML/CSS;Java;JavaScript;SQL;TypeScript
# 10026        9000000.0                                                NaN
# 37353        6890299.0            HTML/CSS;JavaScript;Ruby;SQL;TypeScript
# 30729        6371285.0    Bash/Shell (all shells);Elixir;Go;Kotlin;Python
# 40419        6000000.0  Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# ...

# %%
df_lang  = df['LanguageHaveWorkedWith'].str.split(';').explode().value_counts()

# %%
df['LanguageHaveWorkedWith'].str.split(';').explode()
# Out:
# ResponseId
# 34268           NaN
# 28701            C#
# 28701      HTML/CSS
# 28701    JavaScript
# 28701           SQL
#             ...
# 49186           NaN
# 49187           NaN
# 49188           NaN
# 49190           NaN
# 49191           NaN
# Name: LanguageHaveWorkedWith, Length: 212104, dtype: str

# %%
df_lang.sort_values().nlargest(10)
# Out:
# LanguageHaveWorkedWith
# JavaScript                 21005
# HTML/CSS                   19698
# SQL                        18633
# Python                     18410
# Bash/Shell (all shells)    15503
# TypeScript                 13859
# Java                        9358
# C#                          8852
# C++                         7485
# PowerShell                  7371
# Name: count, dtype: int64

# %%
df_pyth.columns = df_pyth.columns.str.strip().str.lower()

# %%
df_pyth
# Out:
#                                                     num_users  numpython_user  \
# Country
# United States Of America                                 7233            4221
# Germany                                                  3025            1685
# India                                                    2547            1162
# United Kingdom Of Great Britain And Northern Ir...       2042            1027
# France                                                   1409             820
# ...                                                       ...             ...
# Guinea-Bissau                                               1               1
# Niger                                                       1               1
# Palau                                                       1               1
# San Marino                                                  1               0
# Timor-Leste                                                 1               0
#
# ...

# %%
df= df.dropna(subset= ['LanguageHaveWorkedWith', 'Country'])

# %%
df_lang = df[['LanguageHaveWorkedWith', 'Country']].copy()
df_lang
# Out:
#                                        LanguageHaveWorkedWith      Country
# ResponseId
# 28701                   C#;HTML/CSS;JavaScript;SQL;TypeScript      Ukraine
# 45972                                             Java;Kotlin  Netherlands
# 48429       Assembly;C#;GDScript;HTML/CSS;JavaScript;Micro...      Ukraine
# 24901                 HTML/CSS;Java;JavaScript;SQL;TypeScript        India
# 37353                 HTML/CSS;JavaScript;Ruby;SQL;TypeScript      Ukraine
# ...                                                       ...          ...
# 484         Bash/Shell (all shells);HTML/CSS;JavaScript;PH...     Zimbabwe
# 4062          Bash/Shell (all shells);C++;PowerShell;Python;R     Zimbabwe
# 13949                                     HTML/CSS;Python;SQL     Zimbabwe
# 41124                                             Java;Python     Zimbabwe
# 41192                                                   R;SQL     Zimbabwe
#
# [31671 rows x 2 columns]

# %%
df_lang['language'] = df_lang['LanguageHaveWorkedWith'].str.split(';').explode('language')

# %%
df_lang.columns = df_lang.columns.str.lower()
df_lang
# Out:
#                                        languagehaveworkedwith      country  \
# ResponseId
# 28701                   C#;HTML/CSS;JavaScript;SQL;TypeScript      Ukraine
# 45972                                             Java;Kotlin  Netherlands
# 48429       Assembly;C#;GDScript;HTML/CSS;JavaScript;Micro...      Ukraine
# 24901                 HTML/CSS;Java;JavaScript;SQL;TypeScript        India
# 37353                 HTML/CSS;JavaScript;Ruby;SQL;TypeScript      Ukraine
# ...                                                       ...          ...
# 484         Bash/Shell (all shells);HTML/CSS;JavaScript;PH...     Zimbabwe
# 4062          Bash/Shell (all shells);C++;PowerShell;Python;R     Zimbabwe
# 13949                                     HTML/CSS;Python;SQL     Zimbabwe
# 41124                                             Java;Python     Zimbabwe
# 41192                                                   R;SQL     Zimbabwe
#
#                            language
# ResponseId
# ...

# %%
df_lang['language'] = df['LanguageHaveWorkedWith'].str.split(';').explode('language')
df_lang['country'] = df['Country']
df_lang
# Out:
#                                        languagehaveworkedwith      country  \
# ResponseId
# 28701                   C#;HTML/CSS;JavaScript;SQL;TypeScript      Ukraine
# 45972                                             Java;Kotlin  Netherlands
# 48429       Assembly;C#;GDScript;HTML/CSS;JavaScript;Micro...      Ukraine
# 24901                 HTML/CSS;Java;JavaScript;SQL;TypeScript        India
# 37353                 HTML/CSS;JavaScript;Ruby;SQL;TypeScript      Ukraine
# ...                                                       ...          ...
# 484         Bash/Shell (all shells);HTML/CSS;JavaScript;PH...     Zimbabwe
# 4062          Bash/Shell (all shells);C++;PowerShell;Python;R     Zimbabwe
# 13949                                     HTML/CSS;Python;SQL     Zimbabwe
# 41124                                             Java;Python     Zimbabwe
# 41192                                                   R;SQL     Zimbabwe
#
#                            language
# ResponseId
# ...

# %%
lang_by_country = df_lang.groupby(['language', 'country']).size().reset_index(name='count')

# %%
lang_by_country.head(25)
# Out:
#     language                                            country  count
# 0        Ada                                          Australia      1
# 1        Ada                                            Austria      1
# 2        Ada                                             Canada      1
# 3        Ada                                     Czech Republic      2
# 4        Ada                                             France      2
# 5        Ada                                            Germany      5
# 6        Ada                                 Hong Kong (S.A.R.)      1
# 7        Ada                                              Italy      2
# 8        Ada                                              Japan      1
# 9        Ada                                        Netherlands      1
# 10       Ada                                             Norway      1
# 11       Ada                                           Pakistan      1
# ...

# %%
top_country_lang = lang_by_country.sort_values(['country', 'count'], ascending = [True, False]).groupby('country').head(1)

# %%
top_country_lang
# Out:
#                      language                               country  count
# 940                  HTML/CSS                           Afghanistan      2
# 941                  HTML/CSS                               Albania      4
# 942                  HTML/CSS                               Algeria      6
# 298                        C#                               Andorra      2
# 877                    Groovy                                Angola      1
# ...                       ...                                   ...    ...
# 1962                   Python  Venezuela, Bolivarian Republic of...      9
# 1284               JavaScript                              Viet Nam     17
# 1060                 HTML/CSS                                 Yemen      3
# 2297                      SQL                                Zambia      3
# 198   Bash/Shell (all shells)                              Zimbabwe      2
#
# [174 rows x 3 columns]

# %%
pivot = lang_by_country.pivot(index= 'country', columns='language', values='count').fillna(0)
pivot
# Out:
# language                              Ada  Assembly  Bash/Shell (all shells)  \
# country
# Afghanistan                           0.0       0.0                      0.0
# Albania                               0.0       1.0                      2.0
# Algeria                               0.0       0.0                      5.0
# Andorra                               0.0       0.0                      0.0
# Angola                                0.0       0.0                      0.0
# ...                                   ...       ...                      ...
# Venezuela, Bolivarian Republic of...  0.0       0.0                      2.0
# Viet Nam                              0.0       1.0                     13.0
# Yemen                                 0.0       0.0                      1.0
# Zambia                                0.0       0.0                      2.0
# Zimbabwe                              0.0       0.0                      2.0
#
# ...

# %%
top_lang_by_country = lang_by_country.sort_values(by=['country', 'count'], ascending = [True, False]).groupby('country').head(2)

# %%
top_lang_by_country.tail(2)
# Out:
#                     language   country  count
# 198  Bash/Shell (all shells)  Zimbabwe      2
# 294                        C  Zimbabwe      2

# %%
df_na = df[['LearnCode', 'TechEndorseIntro', 'ToolCountWork', 'Country']].copy()

# %%
df_na
# Out:
#                                                     LearnCode  \
# ResponseId
# 28701                                                     NaN
# 45972                        Colleague or on-the-job training
# 48429       Other online resources (e.g. standard search, ...
# 24901       Online Courses or Certification (includes all ...
# 37353                                                     NaN
# ...                                                       ...
# 484         Online Courses or Certification (includes all ...
# 4062        Books / Physical media;AI CodeGen tools or AI-...
# 13949       Online Courses or Certification (includes all ...
# 41124                                                     NaN
# 41192       Online Courses or Certification (includes all ...
#
#             TechEndorseIntro  ToolCountWork      Country
# ResponseId
# 28701                   Work           10.0      Ukraine
# 45972                   Work            NaN  Netherlands
# ...

# %%
df_na.dropna(axis= 'index', how= 'any', subset= ['LearnCode', 'ToolCountWork'], inplace=True)

# %%
df_na.tail(20)
# Out:
#                                                     LearnCode  \
# ResponseId
# 32228       Videos (not associated with specific online co...
# 32333       Online Courses or Certification (includes all ...
# 35677       Online Courses or Certification (includes all ...
# 35715       Online Courses or Certification (includes all ...
# 35859       Online Courses or Certification (includes all ...
# 36295       Online Courses or Certification (includes all ...
# 37853       Online Courses or Certification (includes all ...
# 40383       Stack Overflow or Stack Exchange;AI CodeGen to...
# 41506       Stack Overflow or Stack Exchange;Technical doc...
# 42909       Other online resources (e.g. standard search, ...
# 43806       Online Courses or Certification (includes all ...
# 44656       Online Courses or Certification (includes all ...
# 46126       Other online resources (e.g. standard search, ...
# 47602                        Colleague or on-the-job training
# ...

# %%
df_na['Country'].unique
# Out:
# <bound method Series.unique of ResponseId
# 24901                       India
# 30729                      Brazil
# 48024                   Australia
# 28059    United States of America
# 34976    United States of America
#                    ...
# 37309                      Zambia
# 484                      Zimbabwe
# 4062                     Zimbabwe
# 13949                    Zimbabwe
# 41192                    Zimbabwe
# Name: Country, Length: 18742, dtype: str>

# %%
df_na.isna()
# Out:
#             LearnCode  TechEndorseIntro  ToolCountWork  Country
# ResponseId
# 24901           False             False          False    False
# 30729           False             False          False    False
# 48024           False             False          False    False
# 28059           False             False          False    False
# 34976           False             False          False    False
# ...               ...               ...            ...      ...
# 37309           False             False          False    False
# 484             False             False          False    False
# 4062            False             False          False    False
# 13949           False             False          False    False
# 41192           False             False          False    False
#
# [18742 rows x 4 columns]

# %%
df_nan = df[['LearnCode', 'TechEndorseIntro', 'ToolCountWork', 'Country']].copy()

# %%
df_nan.fillna(0)
# Out:
#                                                     LearnCode  \
# ResponseId
# 28701                                                       0
# 45972                        Colleague or on-the-job training
# 48429       Other online resources (e.g. standard search, ...
# 24901       Online Courses or Certification (includes all ...
# 37353                                                       0
# ...                                                       ...
# 484         Online Courses or Certification (includes all ...
# 4062        Books / Physical media;AI CodeGen tools or AI-...
# 13949       Online Courses or Certification (includes all ...
# 41124                                                       0
# 41192       Online Courses or Certification (includes all ...
#
#             TechEndorseIntro  ToolCountWork      Country
# ResponseId
# 28701                   Work           10.0      Ukraine
# 45972                   Work            0.0  Netherlands
# ...

# %%
df_nan.dtypes
# Out:
# LearnCode               str
# TechEndorseIntro        str
# ToolCountWork       float64
# Country                 str
# dtype: object

# %%
df_nan['ToolCountWork'].agg(['mean', 'median'])
# Out:
# mean      15.149578
# median     6.000000
# Name: ToolCountWork, dtype: float64

# %%
nig_filt = df['Country'] == 'Nigeria'

# %%
df[nig_filt].head(2)
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 19537       I am a developer by profession  25-34 years old
# 22093       I am a developer by profession  25-34 years old
#
#                                                    EdLevel  \
# ResponseId
# 19537       Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 22093         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# ResponseId
# 19537       Independent contractor, freelancer, or self-em...
# 22093       Independent contractor, freelancer, or self-em...
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 19537       Caring for dependents (children, elderly, etc.)     20.0
# 22093           Engaged in paid work (20-29 hours per week)     10.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 19537       No, I am not new to coding and did not learn n...
# ...

# %%
nig_filt.to_csv('data/modified.csv')

# %%
nig_filt.to_excel('data/modified.xlsx')

# %%
test = pd.read_csv('data/modified.csv')

# %%
test['Country'].value_counts()
# Out:
# Country
# False    31525
# True       146
# Name: count, dtype: int64
